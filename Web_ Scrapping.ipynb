# %%
# !pip install requests
# !pip install bs4

# %% [markdown]
# ### Q1. Write a python program to display all the header tags from wikipedia.org.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Main_Page'

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
head = BeautifulSoup(page.text,'html.parser')

# %%
heading_tags =['h1','h2']

# %%
for tags in head.find_all(heading_tags):
    print(tags.name + ' -> ' + tags.text.strip())
# Out:
# h1 -> Main Page
# h1 -> Welcome to Wikipedia
# h2 -> From today's featured article
# h2 -> Did you know ...
# h2 -> In the news
# h2 -> On this day
# h2 -> Today's featured picture
# h2 -> Other areas of Wikipedia
# h2 -> Wikipedia's sister projects
# h2 -> Wikipedia languages

# %% [markdown]
# ### Q.2) Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release) and make data frame.

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
page = requests.get('https://www.imdb.com/list/ls091520106/')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
movie_name = soup.find('h3',class_="lister-item-header")

# %%
movie_list = []
for i in soup.find_all('h3',class_="lister-item-header"):
    movie_list.append(i.text.replace('\n',''))
movie_list
# Out:
# ['1.The Shawshank Redemption(1994)',
#  '2.The Godfather(1972)',
#  '3.The Godfather Part II(1974)',
#  '4.The Dark Knight(2008)',
#  '5.12 Angry Men(1957)',
#  "6.Schindler's List(1993)",
#  '7.The Lord of the Rings: The Return of the King(2003)',
#  '8.Pulp Fiction(1994)',
#  '9.Il buono, il brutto, il cattivo(1966)',
#  '10.Fight Club(1999)',
#  '11.Joker(I) (2019)',
#  '12.The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '13.Forrest Gump(1994)',
#  '14.Inception(2010)',
#  '15.Star Wars: Episode V - The Empire Strikes Back(1980)',
#  '16.The Lord of the Rings: The Two Towers(2002)',
#  '17.The Matrix(1999)',
#  "18.One Flew Over the Cuckoo's Nest(1975)",
#  '19.Goodfellas(1990)',
#  '20.Shichinin no samurai(1954)',
#  '21.Se7en(1995)',
#  '22.Cidade de Deus(2002)',
#  '23.La vita è bella(1997)',
#  '24.The Silence of the Lambs(1991)',
#  '25.Star Wars(1977)',
#  "26.It's a Wonderful Life(1946)",
#  '27.Saving Private Ryan(1998)',
# ...

# %%
year = []
for i in soup.find_all('span',class_="lister-item-year text-muted unbold"):
    year.append(i.text)
year
# Out:
# ['(1994)',
#  '(1972)',
#  '(1974)',
#  '(2008)',
#  '(1957)',
#  '(1993)',
#  '(2003)',
#  '(1994)',
#  '(1966)',
#  '(1999)',
#  '(I) (2019)',
#  '(2001)',
#  '(1994)',
#  '(2010)',
#  '(1980)',
#  '(2002)',
#  '(1999)',
#  '(1975)',
#  '(1990)',
#  '(1954)',
#  '(1995)',
#  '(2002)',
#  '(1997)',
#  '(1991)',
#  '(1977)',
#  '(1946)',
#  '(1998)',
#  '(2001)',
#  '(1999)',
#  '(1994)',
#  '(1962)',
#  '(2014)',
#  '(1995)',
#  '(1994)',
#  '(1998)',
#  '(1985)',
#  '(2002)',
#  '(1936)',
#  '(1991)',
#  '(2011)',
#  '(1960)',
#  '(2000)',
#  '(1931)',
#  '(2006)',
#  '(2014)',
#  '(1968)',
#  '(2006)',
#  '(2019)',
#  '(1942)',
#  '(1988)',
#  '(1954)',
#  '(1988)',
#  '(1979)',
#  '(1981)',
#  '(2000)',
#  '(1979)',
#  '(1940)',
#  '(2006)',
#  '(2018)',
#  '(2012)',
#  '(2018)',
#  '(1980)',
#  '(1957)',
#  '(2008)',
#  '(1950)',
#  '(1964)',
#  '(1997)',
#  '(2003)',
#  '(1957)',
#  '(2012)',
#  '(1984)',
#  '(2019)',
#  '(1986)',
#  '(1999)',
#  '(I) (2017)',
#  '(2016)',
# ...

# %%
Rating = []
for i in soup.find_all('span',class_="ipl-rating-star__rating"):
    Rating.append(i.text)
    
Rating
# Out:
# ['9.3',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '9.2',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '9',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '9',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '9',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
# ...

# %% [markdown]
# ### Q.3) Write a python program to scrape mentioned details from dineout.co.in : i) Restaurant name ii) Cuisine iii) Location iv) Ratings v) Image URL.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://www.dineout.co.in/delhi-restaurants/welcome-back')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
## Find Restaurant Name

# %%
restra_name.text
# Out:
# 'The G.T. RoadM-Block,Connaught Place, Central Delhi'

# %%
restra_name = soup.find('div',class_="restnt-info cursor")

# %%
## Location

# %%
location =[]
for i in soup.find_all('div',class_="restnt-loc ellipsis"):
    location.append(i.text)

# %%
location
# Out:
# ['M-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'The Colonnade,Connaught Place, Central Delhi',
#  'PVR Plaza,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'M-Block,Connaught Place, Central Delhi',
#  'Janpath, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Hotel Palace Heights,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi']

# %%
## Ratings

# %%
rate=[]
for i in soup.find_all('div',class_="restnt-rating rating-4"):
    rate.append(i.text)

# %%
rate
# Out:
# ['4.3',
#  '4',
#  '4.3',
#  '4',
#  '4',
#  '4.1',
#  '4.2',
#  '4.3',
#  '4.4',
#  '4.1',
#  '4.3',
#  '3.7',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.1',
#  '4.4',
#  '4.1']

# %%
## Image url

# %%
images = []
for i in soup.find_all('img',class_="no-img"):
    images.append(i['data-src'])
images
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/m/u/p31393-15972091555f337a43bb961.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/d/f/p19636-16463919576221f295ae1f1.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/t/u/p237-16468990666229af7a72b08.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/e/u/p80493-16064603115fc0a397716de.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/e/y/p20941-168915645564ae7b673b872.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/z/c/p19259-1686039280647eeaf0c8440.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/a/j/p20996-145631488756cd9a0796608.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/n/c/p3007-15706949095d9ee6fd0b8b4.jpg?tr=tr:n-medium',
# ...

# %%
## Cuisine

# %%
cuisines = soup.find_all('span', class_='double-line-ellipsis')

# %%
cuisine_list = []
for cuisine in cuisines:
    cuisine_list.append(cuisine.text.strip())

# %%
cuisine_list
# Out:
# ['₹ 2,000 for 2 (approx) | North Indian',
#  '₹ 1,500 for 2 (approx) | North Indian, Chinese',
#  '₹ 1,300 for 2 (approx) | Chinese, Thai',
#  '₹ 1,400 for 2 (approx) | North Indian, Continental',
#  '₹ 2,500 for 2 (approx) | North Indian, Italian, Chinese, Turkish, Continental',
#  '₹ 1,200 for 2 (approx) | North Indian',
#  '₹ 2,000 for 2 (approx) | Continental, Asian, Italian, North Indian',
#  '₹ 1,500 for 2 (approx) | Tibetan, Nepalese',
#  '₹ 2,000 for 2 (approx) | Italian, Beverages',
#  '₹ 2,000 for 2 (approx) | Modern Indian, Continental, Finger Food',
#  '₹ 2,700 for 2 (approx) | North Indian, Chinese, Continental',
#  '₹ 2,200 for 2 (approx) | North Indian, Mughlai',
#  '₹ 2,200 for 2 (approx) | Chinese, Thai, Continental, North Indian, Asian',
#  '₹ 2,000 for 2 (approx) | North Indian, Chinese, Italian, Continental',
#  '₹ 2,400 for 2 (approx) | North Indian, European, Fast Food, Italian, Continental',
#  '₹ 500 for 2 (approx) | Fast Food',
# ...

# %% [markdown]
# ### Q. 4) Write s python program to display list of respected former finance minister of India(i.e. Name , Term of office) from https://presidentofindia.nic.in/former-presidents.htm and make data frame.

# %%
url = requests.get('https://presidentofindia.nic.in/former-presidents')

# %%
soup = BeautifulSoup(url.text)

# %%
name= []
for i in soup.find_all('div',class_= "desc-sec"):
    name.append(i.text.replace('\n',' '))
name
# Out:
# [' Shri Ram Nath Kovind 14th President of India ',
#  ' Shri Pranab Mukherjee 13th President of India ',
#  ' Smt Pratibha Devisingh Patil 12th President of India ',
#  ' DR. A.P.J. Abdul Kalam 11th President of India ',
#  ' Shri K. R. Narayanan 10th President of India ',
#  ' Dr Shankar Dayal Sharma 9th  President of India ',
#  ' Shri R Venkataraman 8th President of India ',
#  ' Giani Zail Singh 7th President of India ',
#  ' Shri Neelam Sanjiva Reddy 6th President of India ',
#  ' Dr. Fakhruddin Ali Ahmed 5th President of India ',
#  ' Shri Varahagiri Venkata Giri 4th President of India ',
#  ' Dr. Zakir Husain 3rd President of India ',
#  ' Dr. Sarvepalli Radhakrishnan 2nd President of India ',
#  ' Dr. Rajendra Prasad 1st President of India ']
